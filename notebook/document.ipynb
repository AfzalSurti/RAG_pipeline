# %% [markdown]
# ### Data Ingestion

# %%
# Document Data Structure

# The LangChain Document data structure is used to store data extracted from
# different sources such as PDFs, HTML files, CSVs, and Excel files.
# It organizes the data in a structured format so that it can be used for
# further processing and analysis in applications like RAG pipelines.

# A Document mainly has two attributes:

# 1. page_content:
#    This contains the actual content/text extracted from the specific file.

# 2. metadata:
#    This contains additional information about the document such as
#    source, file name, page number, or other relevant details.

# data - > extract it into docymrnt dta structure -  parsing(chunking) - embedding -  vector DB
# after doing this we apply differnet dffernt operation on it like retrival, question answering, summarization, etc.
# similarity search, etc.

# langchain  document loaders  - pdf , csv , websocket , directory, etc.

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is my project related to rag pipeline",
    metadata={
        "source":"txt file",
        "file name":"rag_pipeline.txt",
        "page":1,
        "author":"afzal",
        "date_created":"2024-01-01"
    }

)

doc
# Out:
# Document(metadata={'source': 'txt file', 'file name': 'rag_pipeline.txt', 'page': 1, 'author': 'afzal', 'date_created': '2024-01-01'}, page_content='this is my project related to rag pipeline')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_info.txt":"""🐍 Python  Short Notes (Apt Format)
What is Python?

Python is a high-level, interpreted, general-purpose programming language known for its simple syntax and readability.

Created by: Guido van Rossum (1991)

Philosophy: “Write less, do more.”

Key Features of Python

Easy to learn and write (English-like syntax)

Interpreted language (runs line-by-line)

Dynamically typed (no need to declare data types)

Cross-platform (Windows, Linux, macOS)

Large standard library (batteries included)

Supports OOP, Functional, Procedural programming

Open-source and free

Where Python is Used

Artificial Intelligence / Machine Learning

Data Science & Data Analysis

Web Development (Backend APIs)

Automation & Scripting

Cybersecurity Tools

Scientific Computing

DevOps & Cloud Tools

Web Scraping & Bots

Why Python is So Popular in AI

Python acts as a glue language:

You write logic in Python

Heavy computation runs in optimized C/C++ libraries

Gives simplicity + performance together

That’s why almost all AI frameworks support Python.

Basic Python Example
# Variable
name = "Afzal"

# Output
print("Hello", name)

# Condition
if name == "Afzal":
    print("Learning Python")

How Python Executes Code
Source Code (.py)
     ↓
Python Interpreter
     ↓
Bytecode (.pyc)
     ↓
Python Virtual Machine (PVM)
     ↓
Output


Python is interpreted, not compiled like C/C++.

Important Concepts to Learn

Variables & Data Types

Lists, Tuples, Dictionaries

Functions

Object-Oriented Programming

Modules & Packages

Exception Handling

File Handling

Virtual Environments

Libraries & Frameworks

Important Libraries

NumPy → Numerical computing

Pandas → Data handling

Matplotlib / Seaborn → Visualization

Scikit-learn → Machine Learning

TensorFlow / PyTorch → Deep Learning

FastAPI / Flask / Django → Web development

Transformers / LangChain → GenAI

Python vs Other Languages
Feature	Python	C++	Java
Ease of Use	Very Easy	Hard	Moderate
Development Speed	Fast	Slow	Medium
Performance	Moderate	Very High	High
AI/ML Support	Excellent	Poor	Limited""",

"../data/text_files/java_info.txt":"""☕ JAVA  Quick Notes (Revision Format)

What is Java?
Java is a high-level, object-oriented, platform-independent programming language
developed by Sun Microsystems (1995), now owned by Oracle.

Principle: "Write Once, Run Anywhere (WORA)"

--------------------------------------------------

Key Features of Java

✔ Object-Oriented (Everything is based on classes & objects)
✔ Platform Independent (Runs on JVM, not OS)
✔ Strongly Typed (Type must be declared)
✔ Compiled + Interpreted
✔ Automatic Memory Management (Garbage Collection)
✔ Secure and Robust
✔ Multithreading Support
✔ Large Ecosystem & Libraries

--------------------------------------------------

How Java Works (Execution Flow)

Source Code (.java)
       ↓
Java Compiler (javac)
       ↓
Bytecode (.class)
       ↓
JVM (Java Virtual Machine)
       ↓
Machine Code (runs on any OS)

👉 JVM makes Java platform-independent.

--------------------------------------------------

Basic Java Example

public class Main {
    public static void main(String[] args) {
        String name = "Afzal";
        System.out.println("Hello " + name);
    }
}

--------------------------------------------------

Important Components of Java

1. JDK (Java Development Kit)
   → Tools to develop Java programs (compiler, debugger)

2. JRE (Java Runtime Environment)
   → Provides libraries + JVM to run Java programs

3. JVM (Java Virtual Machine)
   → Executes bytecode and makes Java portable

--------------------------------------------------

Core Concepts You Must Know

• Classes & Objects
• Inheritance
• Polymorphism
• Encapsulation
• Abstraction
• Interfaces
• Exception Handling
• Collections Framework
• Multithreading
• File Handling

--------------------------------------------------

Java Data Types

Primitive:
int, float, double, char, boolean, byte, short, long

Non-Primitive:
String, Arrays, Classes, Interfaces

--------------------------------------------------

Java vs Python

Feature        Java                     Python
--------------------------------------------------
Typing         Static                   Dynamic
Speed          Faster                   Slower
Syntax         Verbose                  Simple
Use Case       Enterprise Apps          AI / Automation
Compilation    Bytecode via JVM         Interpreted

--------------------------------------------------

Where Java is Used

✔ Enterprise Applications (Banking, ERP)
✔ Android Development
✔ Backend Systems (Spring Boot)
✔ Distributed Systems
✔ Big Data Tools (Hadoop, Kafka)
✔ High-performance Server Apps

--------------------------------------------------

Why Java is Still Important

• Massive industry adoption
• Strong type safety for large systems
• Excellent for scalable backend systems
• Used in real-world production environments

--------------------------------------------------

One-Line Definition (For Revision)

Java is a platform-independent, object-oriented language designed
for building secure, scalable, enterprise-level applications.
"""
}

for filepath,content in sample_texts.items():
    with open(filepath,"w",encoding="utf-8") as f:
        f.write(content)


print("data is written to file successfully")
# Out:
# data is written to file successfully

# %%
### text loaders
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_info.txt", encoding="utf-8")
document=loader.load()
print(document)

if document:
	print(document[0].metadata)
# Out:
# [Document(metadata={'source': '../data/text_files/python_info.txt'}, page_content='🐍 Python  Short Notes (Apt Format)\nWhat is Python?\n\nPython is a high-level, interpreted, general-purpose programming language known for its simple syntax and readability.\n\nCreated by: Guido van Rossum (1991)\n\nPhilosophy: “Write less, do more.”\n\nKey Features of Python\n\nEasy to learn and write (English-like syntax)\n\nInterpreted language (runs line-by-line)\n\nDynamically typed (no need to declare data types)\n\nCross-platform (Windows, Linux, macOS)\n\nLarge standard library (batteries included)\n\nSupports OOP, Functional, Procedural programming\n\nOpen-source and free\n\nWhere Python is Used\n\nArtificial Intelligence / Machine Learning\n\nData Science & Data Analysis\n\nWeb Development (Backend APIs)\n\nAutomation & Scripting\n\nCybersecurity Tools\n\nScientific Computing\n\nDevOps & Cloud Tools\n\nWeb Scraping & Bots\n\nWhy Python is So Popular in AI\n\nPython acts as a glue language:\n\
# ...

# %%
## directory loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt" , # 
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"}, 
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\java_info.txt'}, page_content='☕ JAVA  Quick Notes (Revision Format)\n\nWhat is Java?\nJava is a high-level, object-oriented, platform-independent programming language\ndeveloped by Sun Microsystems (1995), now owned by Oracle.\n\nPrinciple: "Write Once, Run Anywhere (WORA)"\n\n--------------------------------------------------\n\nKey Features of Java\n\n✔ Object-Oriented (Everything is based on classes & objects)\n✔ Platform Independent (Runs on JVM, not OS)\n✔ Strongly Typed (Type must be declared)\n✔ Compiled + Interpreted\n✔ Automatic Memory Management (Garbage Collection)\n✔ Secure and Robust\n✔ Multithreading Support\n✔ Large Ecosystem & Libraries\n\n--------------------------------------------------\n\nHow Java Works (Execution Flow)\n\nSource Code (.java)\n       ↓\nJava Compiler (javac)\n       ↓\nBytecode (.class)\n       ↓\nJVM (Java Virtual Machine)\n       ↓\nMachine Code (runs on any OS)\n\n👉 JVM makes Java platform-i
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader , PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdf1",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'producer': '', 'creator': 'Google Sheets', 'creationdate': '', 'source': '..\\data\\pdf1\\MSU Baroda _ OA Shortlist.pdf', 'file_path': '..\\data\\pdf1\\MSU Baroda _ OA Shortlist.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Name\nEmail\nPhone No.\nGraduation\nCollege Name\nVanzara Jahnvi RajeshBhai\nvanzarajahnvi19@gmail.com\n7046336694\n2027\nMaharaja Sayajirao University of Baroda\nRonak Kumar Singh\nronaksingh201106@gmail.com\n9023684742\n2027\nMaharaja Sayajirao University of Baroda\nPatel Amaan\npa8131895@gmail.com\n8866292480\n2027\nMaharaja Sayajirao University of Baroda\nOm Vataliya\nomvataliya23@gmail.com\n6351497589\n2027\nMaharaja Sayajirao University of Baroda\nPatel Amaan\npa8131895@gmail.com\n8866292480\n2027\nMaharaja Sayajirao University of Baroda\nVrutant Panchal\nvrutantpanchal1454@gmail.com\n8141824
# ...

# %%
## csv loader 

from langchain_community.document_loaders import CSVLoader

csv_loader=CSVLoader(
    file_path="../data/csv/employee.csv",
    encoding="utf-8"
)

documents_csv = csv_loader.load()
documents_csv
# Out:
# [Document(metadata={'source': '../data/csv/employee.csv', 'row': 0}, page_content='ID: 1\nName: Ishaan\nAge: 30\nCity: Vadodara\nSalary: 34658\nJoin_Date: 2024-02-09'),
#  Document(metadata={'source': '../data/csv/employee.csv', 'row': 1}, page_content='ID: 2\nName: Riya\nAge: 27\nCity: Bangalore\nSalary: 32151\nJoin_Date: 2025-05-05'),
#  Document(metadata={'source': '../data/csv/employee.csv', 'row': 2}, page_content='ID: 3\nName: Riya\nAge: 54\nCity: Ahmedabad\nSalary: 28361\nJoin_Date: 2025-09-25'),
#  Document(metadata={'source': '../data/csv/employee.csv', 'row': 3}, page_content='ID: 4\nName: Ishaan\nAge: 42\nCity: Jaipur\nSalary: 42643\nJoin_Date: 2025-02-28'),
#  Document(metadata={'source': '../data/csv/employee.csv', 'row': 4}, page_content='ID: 5\nName: Ishaan\nAge: 25\nCity: Surat\nSalary: 67838\nJoin_Date: 2024-11-29'),
# ...
